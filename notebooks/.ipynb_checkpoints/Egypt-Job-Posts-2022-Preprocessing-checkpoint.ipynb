# %%
import pandas as pd

# %%
jobsDF = pd.read_csv('../data/Egypt Job Posts 22.csv')
jobsDF
# Out:
#                                                    Title  \
# 0                              Banking Call Center Agent
# 1                              Call Center Agent Banking
# 2                             Odoo Functional Consultant
# 3                                         CRM Specialist
# 4                Core Banking Technical Support Engineer
# ...                                                  ...
# 15203                                  logistics Officer
# 15204                                      IOS developer
# 15205          خدمة عملاء توشيبا بالمقر الرئيسى العباسية
# 15206  IT specialist with LMS and support Experience ...
# 15207                                 مندوب مبيعات خارجي
#
#                    Company Name Area Governorate Country   Job Type  \
# 0      Raya Customer Experience  NaN       Cairo   Egypt  Full Time
# 1      Raya Customer Experience  NaN       Maadi   Egypt  Full Time
# 2                      Centione  NaN   Nasr City   Egypt  Full Time
# ...

# %%
jobsDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15208 entries, 0 to 15207
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   15208 non-null  object
#  1   Company Name            15179 non-null  object
#  2   Area                    367 non-null    object
#  3   Governorate             13521 non-null  object
#  4   Country                 15208 non-null  object
#  5   Job Type                11866 non-null  object
#  6   Experience Level        12317 non-null  object
#  7   Min Yrs of Excperience  11663 non-null  float64
#  8   Max Yrs of Experience   8957 non-null   float64
#  9   Gender                  188 non-null    object
#  10  Source                  15208 non-null  object
#  11  Skills - 1              11866 non-null  object
#  12  Skills - 1.1            10959 non-null  object
#  13  Skills - 1.2            5197 non-null   object
# ...

# %%
jobsDF.isna().sum()
# Out:
# Title                         0
# Company Name                 29
# Area                      14841
# Governorate                1687
# Country                       0
# Job Type                   3342
# Experience Level           2891
# Min Yrs of Excperience     3545
# Max Yrs of Experience      6251
# Gender                    15020
# Source                        0
# Skills - 1                 3342
# Skills - 1.1               4249
# Skills - 1.2              10011
# Skills - 1.3               6858
# Skills - 2                12628
# Skills - 2.1               8628
# Skills - 3                 8901
# Skills - 3.1              11349
# Skills - 3.2              13502
# Skills - 3.3              11984
# Skills - 4                12036
# Skills - 5                11862
# Skills - 6                15073
# dtype: int64

# %%
clean_data = jobsDF.drop(['Area', 'Gender'], axis=1)
clean_data
# Out:
#                                                    Title  \
# 0                              Banking Call Center Agent
# 1                              Call Center Agent Banking
# 2                             Odoo Functional Consultant
# 3                                         CRM Specialist
# 4                Core Banking Technical Support Engineer
# ...                                                  ...
# 15203                                  logistics Officer
# 15204                                      IOS developer
# 15205          خدمة عملاء توشيبا بالمقر الرئيسى العباسية
# 15206  IT specialist with LMS and support Experience ...
# 15207                                 مندوب مبيعات خارجي
#
#                    Company Name Governorate Country   Job Type  \
# 0      Raya Customer Experience       Cairo   Egypt  Full Time
# 1      Raya Customer Experience       Maadi   Egypt  Full Time
# 2                      Centione   Nasr City   Egypt  Full Time
# ...

# %%
clean_data.isna().sum()
# Out:
# Title                         0
# Company Name                 29
# Governorate                1687
# Country                       0
# Job Type                   3342
# Experience Level           2891
# Min Yrs of Excperience     3545
# Max Yrs of Experience      6251
# Source                        0
# Skills - 1                 3342
# Skills - 1.1               4249
# Skills - 1.2              10011
# Skills - 1.3               6858
# Skills - 2                12628
# Skills - 2.1               8628
# Skills - 3                 8901
# Skills - 3.1              11349
# Skills - 3.2              13502
# Skills - 3.3              11984
# Skills - 4                12036
# Skills - 5                11862
# Skills - 6                15073
# dtype: int64

# %%
clean_data = clean_data.dropna(axis=0, how='any', subset=['Company Name'])
clean_data.isna().sum()
# Out:
# Title                         0
# Company Name                  0
# Governorate                1687
# Country                       0
# Job Type                   3315
# Experience Level           2891
# Min Yrs of Excperience     3517
# Max Yrs of Experience      6223
# Source                        0
# Skills - 1                 3315
# Skills - 1.1               4221
# Skills - 1.2               9982
# Skills - 1.3               6830
# Skills - 2                12599
# Skills - 2.1               8600
# Skills - 3                 8873
# Skills - 3.1              11320
# Skills - 3.2              13473
# Skills - 3.3              11956
# Skills - 4                12008
# Skills - 5                11833
# Skills - 6                15044
# dtype: int64

# %%
values = {'Governorate':'Cairo'}
clean_data.loc[:,"Governorate"] = clean_data.loc[:,"Governorate"].fillna(value=values)
clean_data.isna().sum()
# Out:
# C:\Users\Shrook\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# Title                         0
# Company Name                  0
# Governorate                1687
# Country                       0
# Job Type                   3315
# Experience Level           2891
# Min Yrs of Excperience     3517
# Max Yrs of Experience      6223
# Source                        0
# Skills - 1                 3315
# Skills - 1.1               4221
# Skills - 1.2               9982
# Skills - 1.3               6830
# Skills - 2                12599
# Skills - 2.1               8600
# Skills - 3                 8873
# ...

# %%
#filling data of Experience Level
# if clean_data["Min Yrs of Excperience"] <= 1:
#     juniorLevel = True
# elif clean_data["Min Yrs of Excperience"] >= 5:
#     seniorLevel = True
