# %%
import pandas as pd

# %%
jobsDF = pd.read_csv('../data/Egypt Job Posts 22.csv')
jobsDF
# Out:
#                                                    Title  \
# 0                              Banking Call Center Agent
# 1                              Call Center Agent Banking
# 2                             Odoo Functional Consultant
# 3                                         CRM Specialist
# 4                Core Banking Technical Support Engineer
# ...                                                  ...
# 15203                                  logistics Officer
# 15204                                      IOS developer
# 15205          خدمة عملاء توشيبا بالمقر الرئيسى العباسية
# 15206  IT specialist with LMS and support Experience ...
# 15207                                 مندوب مبيعات خارجي
#
#                    Company Name Area Governorate Country   Job Type  \
# 0      Raya Customer Experience  NaN       Cairo   Egypt  Full Time
# 1      Raya Customer Experience  NaN       Maadi   Egypt  Full Time
# 2                      Centione  NaN   Nasr City   Egypt  Full Time
# ...
